# %%
pwd
# Out:
# 'C:\\Users\\1\\cp8'

# %%
import pandas as pd

# %%
bowlingavg_dataset=pd.read_csv("bowlingavg.csv")

# %%
bowlingavg_dataset
# Out:
#              PlayerName       Span  Mat  Overs  Maiden  Runs  Wkts   BBI  \
# 0         Faheem Ashraf  2018-2021   35  117.5       1   932    50  6/19
# 1            Wahab Riaz  2016-2021   59  218.5       0  1574    84  4/17
# 2           Imran Tahir  2018-2021   21   69.0       1   506    26  3/19
# 3      Mohammad Hasnain  2019-2021   21   78.5       1   655    33  4/25
# 4             Hasan Ali  2016-2021   49  181.1       1  1324    65  4/15
# 5   Shaheen Shah Afridi  2018-2021   31  114.3       3   881    43   5/4
# 6             SP Narine  2017-2018   17   66.0       0   411    20  3/28
# 7         Mohammad Sami  2016-2019   36  127.0       1   875    42   5/8
# 8             Umer Khan  2019-2020   17   51.0       0   397    19  3/22
# 9              TS Mills  2017-2020   22   78.3       0   612    28  3/20
# 10       Mohammad Ilyas  2019-2021   19   49.4       0   426    19  3/27
# 11             SR Patel  2018-2021   33   89.0       1   667    29   4/5
# ...

# %%
bowlingavg_dataset.shape
# Out:
# (48, 13)

# %%
bowlingavg_dataset.columns
# Out:
# Index(['PlayerName', 'Span', 'Mat', 'Overs', 'Maiden', 'Runs', 'Wkts', 'BBI',
#        'Ave', 'Economy', 'SR', '4s', '5S'],
#       dtype='object')

# %%
bowlingavg_dataset[['Ave', 'SR']].head()
# Out:
#      Ave    SR
# 0  18.64  14.1
# 1  18.73  15.6
# 2  19.46  15.9
# 3  19.84  14.3
# 4  20.36  16.7

# %%
bowlingavg_dataset.loc[1:3]
# Out:
#          PlayerName       Span  Mat  Overs  Maiden  Runs  Wkts   BBI    Ave  \
# 1        Wahab Riaz  2016-2021   59  218.5       0  1574    84  4/17  18.73
# 2       Imran Tahir  2018-2021   21   69.0       1   506    26  3/19  19.46
# 3  Mohammad Hasnain  2019-2021   21   78.5       1   655    33  4/25  19.84
#
#    Economy    SR  4s  5S
# 1     7.19  15.6   1   0
# 2     7.33  15.9   0   0
# 3     8.30  14.3   2   0

# %%
bowlingavg_dataset[bowlingavg_dataset.Maiden == 1].head()
# Out:
#          PlayerName       Span  Mat  Overs  Maiden  Runs  Wkts   BBI    Ave  \
# 0     Faheem Ashraf  2018-2021   35  117.5       1   932    50  6/19  18.64
# 2       Imran Tahir  2018-2021   21   69.0       1   506    26  3/19  19.46
# 3  Mohammad Hasnain  2019-2021   21   78.5       1   655    33  4/25  19.84
# 4         Hasan Ali  2016-2021   49  181.1       1  1324    65  4/15  20.36
# 7     Mohammad Sami  2016-2019   36  127.0       1   875    42   5/8  20.83
#
#    Economy    SR  4s  5S
# 0     7.90  14.1   1   1
# 2     7.33  15.9   0   0
# 3     8.30  14.3   2   0
# 4     7.30  16.7   3   0
# 7     6.88  18.1   0   1

# %%
bowlingavg_dataset[bowlingavg_dataset.Maiden.isin([0,1])].head()
# Out:
#          PlayerName       Span  Mat  Overs  Maiden  Runs  Wkts   BBI    Ave  \
# 0     Faheem Ashraf  2018-2021   35  117.5       1   932    50  6/19  18.64
# 1        Wahab Riaz  2016-2021   59  218.5       0  1574    84  4/17  18.73
# 2       Imran Tahir  2018-2021   21   69.0       1   506    26  3/19  19.46
# 3  Mohammad Hasnain  2019-2021   21   78.5       1   655    33  4/25  19.84
# 4         Hasan Ali  2016-2021   49  181.1       1  1324    65  4/15  20.36
#
#    Economy    SR  4s  5S
# 0     7.90  14.1   1   1
# 1     7.19  15.6   1   0
# 2     7.33  15.9   0   0
# 3     8.30  14.3   2   0
# 4     7.30  16.7   3   0

# %%
# %matplotlib inline

# %%
bowlingavg_dataset.Mat.hist()

# %%
bowlingavg_dataset.Runs.hist()
